# %% [markdown]
# # **INTRODUCTION TO TENSORS TUTORIAL**

# %% [markdown]
# # **TENSOR BASICS**

# %%
import torch

# %%
t1=torch.tensor(4.)
t1
# Out:
# tensor(4.)

# %%
t2=torch.tensor([1.,2,3,4,5])
t2
# Out:
# tensor([1., 2., 3., 4., 5.])

# %%
t3=torch.tensor([[1,2,3],[4,5,6]])

# %%
t4=torch.tensor([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
t1.shape
# Out:
# torch.Size([])

# %%
t2.shape
# Out:
# torch.Size([5])

# %%
t3.shape
# Out:
# torch.Size([2, 3])

# %%
t4.shape
# Out:
# torch.Size([2, 2, 2])

# %% [markdown]
# # **AUTOGRAD EXAMPLE**

# %%
x=torch.tensor(4.,requires_grad=True)
w=torch.tensor(5.,requires_grad=True)
b=torch.tensor(6.,requires_grad=True  )
x,w,b
# Out:
# (tensor(4., requires_grad=True),
#  tensor(5., requires_grad=True),
#  tensor(6., requires_grad=True))

# %%
y=w*x+b
y
# Out:
# tensor(26., grad_fn=<AddBackward0>)

# %%
y.backward()

# %%
#Reset gradients

# %%
print("dy/dx",x.grad)
print("dy/dw",w.grad)
print("dy/db",b.grad)
# Out:
# dy/dx tensor(5.)
# dy/dw tensor(4.)
# dy/db tensor(1.)

# %%
#Another function

# %%
z=(w**2)*x+b*w

# %%
z.backward()

# %%
#Reset gradients

# %%
print("dy/dx",x.grad)
print("dy/dw",w.grad)
print("dy/db",b.grad)
# Out:
# dy/dx tensor(30.)
# dy/dw tensor(50.)
# dy/db tensor(6.)

# %% [markdown]
# # **TENSOR OPERATIONS**

# %%
t4=torch.full((2,3),42)
t4
# Out:
# tensor([[42, 42, 42],
#         [42, 42, 42]])

# %%
t5=torch.cat((t3,t4))
t5
# Out:
# tensor([[ 1,  2,  3],
#         [ 4,  5,  6],
#         [42, 42, 42],
#         [42, 42, 42]])

# %%
t8=torch.sin(t5)
t8
# Out:
# tensor([[ 0.8415,  0.9093,  0.1411],
#         [-0.7568, -0.9589, -0.2794],
#         [-0.9165, -0.9165, -0.9165],
#         [-0.9165, -0.9165, -0.9165]])

# %%
t9=t8.reshape(2,2,3)
t9
# Out:
# tensor([[[ 0.8415,  0.9093,  0.1411],
#          [-0.7568, -0.9589, -0.2794]],
#
#         [[-0.9165, -0.9165, -0.9165],
#          [-0.9165, -0.9165, -0.9165]]])

# %% [markdown]
# # **Numpy and tensor**

# %%
import numpy as  np

# %%
c=np.array([[1,2],[3,4]])
c
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
d=torch.from_numpy(c)
d
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
c.dtype,d.dtype
# Out:
# (dtype('int64'), torch.int64)
