# %% [markdown]
# # **LINEAR REGRESSION IN NN MODULE**

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# # **DATA**

# %%
x = torch.randn(10, 1)
true_w = torch.tensor([[2.0]])
true_b = torch.tensor([1.0])

y = x @ true_w + true_b + torch.randn(10, 1) * 0.1

# %% [markdown]
# # **MODEL**

# %%
model = nn.Linear(in_features=1, out_features=1)

# %% [markdown]
# # **LOSS AND OPTIMIZATION**

# %%
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# # **TRAINING LOOP**

# %%
epochs = 100

for epoch in range(epochs):
    y_hat = model(x)
    loss = loss_fn(y_hat, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0, Loss: 5.0227
# Epoch 10, Loss: 2.3232
# Epoch 20, Loss: 1.0781
# Epoch 30, Loss: 0.5039
# Epoch 40, Loss: 0.2389
# Epoch 50, Loss: 0.1167
# Epoch 60, Loss: 0.0602
# Epoch 70, Loss: 0.0341
# Epoch 80, Loss: 0.0220
# Epoch 90, Loss: 0.0163
